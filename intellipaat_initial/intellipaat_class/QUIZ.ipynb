# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car=pd.read_csv('CAR-DETAILS-FROM-CAR-DEKHO.csv')

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
car.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
car.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
car.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
car['transmission'].mode()
# Out:
# 0    Manual
# dtype: object

# %%
x=car['name'].tolist()

# %%
car['name'].unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
X=[i.split() for i in x]

# %%
c=[]
for i in X:
    if i[0]=='Mahindra':
        c.append(i)

# %%
c
# Out:
# [['Mahindra', 'Scorpio', '1.99', 'S10'],
#  ['Mahindra', 'Scorpio', 'LX'],
#  ['Mahindra', 'Jeep', 'CL', '500', 'MDI'],
#  ['Mahindra', 'Scorpio', '1.99', 'S6', 'Plus'],
#  ['Mahindra', 'XUV500', 'W8', '2WD'],
#  ['Mahindra', 'Bolero', '2011-2019', 'SLE'],
#  ['Mahindra', 'Bolero', 'Power', 'Plus', 'SLX'],
#  ['Mahindra', 'Xylo', 'D4'],
#  ['Mahindra', 'Xylo', 'E4', 'BS', 'III'],
#  ['Mahindra', 'Scorpio', 'LX', 'BSIV'],
#  ['Mahindra', 'Quanto', 'C8'],
#  ['Mahindra', 'Bolero', 'Power', 'Plus', 'SLX'],
#  ['Mahindra', 'Xylo', 'E4'],
#  ['Mahindra', 'XUV500', 'W6', '2WD'],
#  ['Mahindra', 'XUV300', 'W8', 'Option'],
#  ['Mahindra', 'Renault', 'Logan', '1.5', 'DLS'],
#  ['Mahindra', 'Scorpio', 'S11', 'BSIV'],
#  ['Mahindra', 'Xylo', 'E4'],
#  ['Mahindra', 'Bolero', 'Power', 'Plus', 'SLX'],
#  ['Mahindra', 'Xylo', 'D2', 'BSIV'],
#  ['Mahindra', 'Bolero', 'SLX', '2WD', 'BSIII'],
#  ['Mahindra', 'Scorpio', 'VLS', 'AT', '2.2', 'mHAWK'],
#  ['Mahindra', 'Bolero', 'SLX'],
# ...

# %%
len(c)
# Out:
# 365

# %%
car['year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
i
# Out:
# ['Renault', 'KWID', 'RXT']

# %%
car.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
col=car.columns

# %%
for i in col:
    if car[i].dtype=='int64':
        plt.boxplot(car[i])
        plt.xlabel(i)
        plt.ylabel('count')
        plt.show()

# %%
for i in col:
    if car[i].dtype=='int64':
        Q1=car[i].quantile(0.25)
        Q3=car[i].quantile(0.75)
        IQR=Q3-Q1
        car=car[(car[i]>=Q1-IQR*1.5)&(car[i]<=Q3+IQR*1.5)]

# %%
for i in col:
    if car[i].dtype=='int64':
        plt.boxplot(car[i])
        plt.xlabel(i)
        plt.ylabel('count')
        plt.show()

# %%
car
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3858 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3858 non-null   object
#  1   year           3858 non-null   int64
#  2   selling_price  3858 non-null   int64
#  3   km_driven      3858 non-null   int64
#  4   fuel           3858 non-null   object
#  5   seller_type    3858 non-null   object
#  6   transmission   3858 non-null   object
#  7   owner          3858 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.3+ KB

# %%
len(car['name'].unique())
# Out:
# 1317

# %%
x=(car['year'].unique()).tolist()
print(type(x))
print(len(car['year'].unique()))
# Out:
# <class 'list'>
# 17

# %%
car['year']=car['year'].map({2004:0, 2005:1, 2006:2, 2007:3, 2008:4, 2009:5, 2010:6, 2011:7, 2012:8, 2013:9, 2014:10, 2015:11, 2016:12, 2017:13, 2018:14, 2019:15, 2020:16})

# %%
x.sort()
print(x)
# Out:
# [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC     3          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor     3         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX     8         600000     100000  Diesel
# 3    Datsun RediGO T Option    13         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC    10         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
car['fuel']=car['fuel'].map({'Petrol':0, 'Diesel':1, 'CNG':2, 'LPG':3, 'Electric':4})

# %%
car['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
car['seller_type']=car['seller_type'].map({'Individual':0, 'Dealer':1, 'Trustmark Dealer':2})

# %%
car['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
car['transmission']=car['transmission'].map({'Manual':0, 'Automatic':1})

# %%
car['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
car['owner']=car['owner'].map({'First Owner':1, 'Second Owner':2, 'Fourth & Above Owner':4,'Third Owner':3, 'Test Drive Car':0})

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven  fuel  \
# 0             Maruti 800 AC     3          60000      70000     0
# 1  Maruti Wagon R LXI Minor     3         135000      50000     0
# 2      Hyundai Verna 1.6 SX     8         600000     100000     1
# 3    Datsun RediGO T Option    13         250000      46000     0
# 4     Honda Amaze VX i-DTEC    10         450000     141000     1
#
#    seller_type  transmission  owner
# 0            0             0      1
# 1            0             0      1
# 2            0             0      1
# 3            0             0      1
# 4            0             0      2

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression

# %%
#from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for i in col:
    if((car[i].dtype != 'object')& (car[i].dtype != 'charges')):
        col_list.append(i)

# %%
col_list
# Out:
# ['year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner']

# %%
x=car[col_list]

# %%
x
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0        3          60000      70000     0            0             0      1
# 1        3         135000      50000     0            0             0      1
# 2        8         600000     100000     1            0             0      1
# 3       13         250000      46000     0            0             0      1
# 4       10         450000     141000     1            0             0      2
# ...    ...            ...        ...   ...          ...           ...    ...
# 4335    10         409999      80000     1            0             0      2
# 4336    10         409999      80000     1            0             0      2
# 4337     5         110000      83000     0            0             0      2
# 4338    12         865000      90000     1            0             0      1
# 4339    12         225000      40000     0            0             0      1
#
# [3858 rows x 7 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3858 entries, 0 to 4339
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           3858 non-null   int64
#  1   selling_price  3858 non-null   int64
#  2   km_driven      3858 non-null   int64
#  3   fuel           3858 non-null   int64
#  4   seller_type    3858 non-null   int64
#  5   transmission   3858 non-null   int64
#  6   owner          3858 non-null   int64
# dtypes: int64(7)
# memory usage: 241.1 KB

# %%
x.values
# Out:
# array([[     3,  60000,  70000, ...,      0,      0,      1],
#        [     3, 135000,  50000, ...,      0,      0,      1],
#        [     8, 600000, 100000, ...,      0,      0,      1],
#        ...,
#        [     5, 110000,  83000, ...,      0,      0,      2],
#        [    12, 865000,  90000, ...,      0,      0,      1],
#        [    12, 225000,  40000, ...,      0,      0,      1]], dtype=int64)

# %%
for i in range(len(x.columns)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
#from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for i in col:
    if ((car[i].dtype!='object')&(car[i].dtype!='charges')):
        col_list.append(i)

x=car[col_list]
vif_data=pd.DataFrame()
vif_data['feature']= x.columns
vif_data['VIF']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#          feature       VIF
# 0           year  7.748715
# 1  selling_price  7.325858
# 2      km_driven  4.698045
# 3           fuel  2.404522
# 4    seller_type  1.387943
# 5   transmission  1.151540
# 6          owner  4.788687

# %%
car=car.drop(['year'],axis=1)

# %%
col_list=[]
for i in car.columns:
    if ((car[i].dtype!='object')&(car[i].dtype!='charges')):
        col_list.append(i)

x=car[col_list]
vif_data=pd.DataFrame()
vif_data['feature']= x.columns
vif_data['VIF']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
print(vif_data)
# Out:
#          feature       VIF
# 0  selling_price  2.970058
# 1      km_driven  4.690208
# 2           fuel  2.385978
# 3    seller_type  1.379338
# 4   transmission  1.144829
# 5          owner  4.332554

# %%
car.columns
# Out:
# Index(['name', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
x
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner
# 0             60000      70000     0            0             0      1
# 1            135000      50000     0            0             0      1
# 2            600000     100000     1            0             0      1
# 3            250000      46000     0            0             0      1
# 4            450000     141000     1            0             0      2
# ...             ...        ...   ...          ...           ...    ...
# 4335         409999      80000     1            0             0      2
# 4336         409999      80000     1            0             0      2
# 4337         110000      83000     0            0             0      2
# 4338         865000      90000     1            0             0      1
# 4339         225000      40000     0            0             0      1
#
# [3858 rows x 6 columns]

# %%
#x=car.loc[:, ['km_driven','fuel', 'seller_type','transmission', 'owner']]#, 'fuel', 'seller_type','transmission', 'owner']]
x=car.loc[:, ['fuel', 'seller_type','transmission', 'owner']]#, 'fuel', 'seller_type','transmission', 'owner']]
y=car.loc[:,'selling_price']

# %%
x_train ,x_test, y_train, y_test=train_test_split(x,y,train_size=0.7, random_state=0)
#x_train ,x_test, y_train, y_test=train_test_split(x,y,train_size=0.8, random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2700, 4)
# (1158, 4)
# (2700,)
# (1158,)

# %%
x_train.reset_index(drop=True,inplace=True)
x_test.reset_index(drop=True,inplace=True)
y_train.reset_index(drop=True,inplace=True)
y_test.reset_index(drop=True,inplace=True)

# %%
x_train
# Out:
#       fuel  seller_type  transmission  owner
# 0        1            0             0      3
# 1        1            0             0      1
# 2        1            0             0      1
# 3        0            1             0      1
# 4        0            0             0      1
# ...    ...          ...           ...    ...
# 2695     1            0             0      1
# 2696     0            0             0      2
# 2697     0            0             0      1
# 2698     0            0             1      1
# 2699     0            0             0      2
#
# [2700 rows x 4 columns]

# %%
l_model=LinearRegression()

# %%
l_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=l_model.predict(x_train)

# %%
prediction
# Out:
# array([266703.86055086, 477853.06367848, 477853.06367848, ...,
#        349780.06544292, 531785.03938307, 244205.46387911])

# %%
error_pred=pd.DataFrame(columns={'Actual_data','Prediction_data'})

# %%
y_train
# Out:
# 0       315000
# 1       133000
# 2       550000
# 3       330000
# 4       175000
#          ...
# 2695    475000
# 2696    320000
# 2697    750000
# 2698    738000
# 2699     75000
# Name: selling_price, Length: 2700, dtype: int64

# %%
error_pred['Actual_data']=y_train

# %%
len(y_train)
# Out:
# 2700

# %%
error_pred['Prediction_data']=prediction

# %%
error_pred
# Out:
#       Prediction_data  Actual_data
# 0       266703.860551       315000
# 1       477853.063678       133000
# 2       477853.063678       550000
# 3       425212.170545       330000
# 4       349780.065443       175000
# ...               ...          ...
# 2695    477853.063678       475000
# 2696    244205.463879       320000
# 2697    349780.065443       750000
# 2698    531785.039383       738000
# 2699    244205.463879        75000
#
# [2700 rows x 2 columns]

# %%
error_pred['Error']=error_pred['Actual_data']-error_pred['Prediction_data']

# %%
error_pred.head()
# Out:
#    Prediction_data  Actual_data          Error
# 0    266703.860551       315000   48296.139449
# 1    477853.063678       133000 -344853.063678
# 2    477853.063678       550000   72146.936322
# 3    425212.170545       330000  -95212.170545
# 4    349780.065443       175000 -174780.065443

# %%
from sklearn.metrics import *

# %%
r2_on_test=r2_score(y_train,prediction)
#r2_on_test=r2_score(prediction,y_test)
r2_on_test
# Out:
# 0.2400611658943671

# %%
car.columns
# Out:
# Index(['name', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
x_train
# Out:
#       fuel  seller_type  transmission  owner
# 0        1            0             0      3
# 1        1            0             0      1
# 2        1            0             0      1
# 3        0            1             0      1
# 4        0            0             0      1
# ...    ...          ...           ...    ...
# 2695     1            0             0      1
# 2696     0            0             0      2
# 2697     0            0             0      1
# 2698     0            0             1      1
# 2699     0            0             0      2
#
# [2700 rows x 4 columns]

# %%
x_test
# Out:
#       fuel  seller_type  transmission  owner
# 0        0            0             0      1
# 1        1            1             0      2
# 2        0            0             0      1
# 3        0            0             0      1
# 4        0            0             0      2
# ...    ...          ...           ...    ...
# 1153     1            0             0      1
# 1154     1            0             0      4
# 1155     1            0             0      1
# 1156     0            2             0      1
# 1157     0            1             1      1
#
# [1158 rows x 4 columns]

# %%
y_train
# Out:
# 0       315000
# 1       133000
# 2       550000
# 3       330000
# 4       175000
#          ...
# 2695    475000
# 2696    320000
# 2697    750000
# 2698    738000
# 2699     75000
# Name: selling_price, Length: 2700, dtype: int64

# %%
y_test
# Out:
# 0       600000
# 1       199000
# 2       375000
# 3       500000
# 4       300000
#          ...
# 1153    190000
# 1154    135000
# 1155    400000
# 1156    625000
# 1157    300000
# Name: selling_price, Length: 1158, dtype: int64

# %%
car
# Out:
#                                      name  selling_price  km_driven  fuel  \
# 0                           Maruti 800 AC          60000      70000     0
# 1                Maruti Wagon R LXI Minor         135000      50000     0
# 2                    Hyundai Verna 1.6 SX         600000     100000     1
# 3                  Datsun RediGO T Option         250000      46000     0
# 4                   Honda Amaze VX i-DTEC         450000     141000     1
# ...                                   ...            ...        ...   ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000     1
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000     1
# 4337                  Maruti 800 AC BSIII         110000      83000     0
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000     1
# 4339                     Renault KWID RXT         225000      40000     0
#
#       seller_type  transmission  owner
# 0               0             0      1
# ...

# %% [markdown]
# ## PCA - QUIZ

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn import datasets
from sklearn.datasets import load_digits

# %%
data=pd.read_csv('Placement_Data_Full_Class-3.csv')

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data['gender'].value_counts()
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
d=data[data['ssc_p']<50.00]

# %%
d.shape
# Out:
# (11, 15)

# %%
dd=data[(data['hsc_s']=='Arts')&(data['status']=='Not Placed')]

# %%
dd.shape
# Out:
# (5, 15)

# %%
d1=data[data['ssc_p']>80.00]

# %%
d1
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 33      34      F  87.00   Others  65.00   Others   Science     81.00
# 39      40      M  81.00   Others  68.00   Others   Science     64.00
# 43      44      M  87.00   Others  87.00   Others  Commerce     68.00
# 61      62      M  84.20  Central  73.40  Central  Commerce     66.89
# 62      63      F  86.50   Others  64.20   Others   Science     67.40
# 66      67      M  83.00   Others  74.00   Others   Science     66.00
# 67      68      M  80.92   Others  78.50   Others  Commerce     67.00
# 70      71      M  82.00   Others  61.00   Others   Science     62.00
# 72      73      M  84.86   Others  67.00   Others   Science     78.00
# 78      79      M  84.00   Others  90.90   Others   Science     64.50
# ...

# %%
d2=d1[d1['hsc_s']=='Commerce']

# %%
d2
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 43      44      M  87.00   Others  87.00   Others  Commerce     68.00
# 61      62      M  84.20  Central  73.40  Central  Commerce     66.89
# 67      68      M  80.92   Others  78.50   Others  Commerce     67.00
# 85      86      F  83.84   Others  89.83   Others  Commerce     77.20
# 90      91      F  85.00   Others  90.00   Others  Commerce     82.00
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 4    Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# ...

# %%
x=d2['salary'].tolist()

# %%
x.sort()
x
# Out:
# [200000.0,
#  275000.0,
#  300000.0,
#  300000.0,
#  300000.0,
#  300000.0,
#  350000.0,
#  400000.0,
#  400000.0,
#  425000.0]

# %%
x=data.iloc[:,:-2]
y=data['status']

# %%
x
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80
# ...

# %%
from sklearn.preprocessing import StandardScaler  
x_std = StandardScaler().fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-eb8afb98ef43> in <module>
#       1 from sklearn.preprocessing import StandardScaler
# ----> 2 x_std = StandardScaler().fit_transform(x)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
# ...
